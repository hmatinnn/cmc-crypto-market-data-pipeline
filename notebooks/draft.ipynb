# %%
import pandas as pd
import os

# %%
df = pd.read_csv("../api_responses_csv/listing_latest.csv")

# %%
df.columns
# Out:
# Index(['id', 'infinite_supply', 'circulating_supply', 'total_supply',
#        'max_supply', 'date_added', 'num_market_pairs', 'cmc_rank',
#        'last_updated', 'tvl_ratio', 'self_reported_circulating_supply',
#        'self_reported_market_cap', 'minted_market_cap', 'inserted_at'],
#       dtype='str')

# %%
df.isnull().sum()
# Out:
# id                                     0
# infinite_supply                        0
# circulating_supply                     0
# total_supply                           0
# max_supply                          4718
# date_added                             0
# num_market_pairs                       0
# cmc_rank                               0
# last_updated                           0
# tvl_ratio                           9835
# self_reported_circulating_supply    4188
# self_reported_market_cap            4188
# minted_market_cap                      0
# inserted_at                            0
# dtype: int64

# %%
df['inserted_at'].value_counts()
# Out:
# inserted_at
# 2026-07-05 18:48:46    500
# 2026-07-06 05:36:13    500
# 2026-07-07 06:29:52    500
# 2026-07-08 06:13:15    500
# 2026-07-09 07:30:20    500
# 2026-07-10 16:51:20    500
# 2026-07-11 05:55:22    500
# 2026-07-12 12:15:29    500
# 2026-07-14 07:11:59    500
# 2026-07-15 06:56:16    500
# 2026-07-16 06:56:07    500
# 2026-07-17 07:49:31    500
# 2026-07-18 08:07:22    500
# 2026-07-19 00:59:59    500
# 2026-07-20 21:33:20    500
# 2026-07-21 06:34:31    500
# 2026-07-22 08:34:48    500
# 2026-07-23 12:43:50    500
# 2026-07-24 17:49:12    500
# 2026-07-25 21:19:37    500
# 2026-07-27 05:36:26    500
# Name: count, dtype: int64

# %%
df['inserted_at'].value_counts()
# Out:
# inserted_at
# 2026-07-05 18:48:46    400
# 2026-07-06 05:36:13    400
# 2026-07-07 06:29:52    400
# 2026-07-08 06:13:15    400
# 2026-07-09 07:30:20    400
# 2026-07-10 16:51:20    400
# 2026-07-11 05:55:22    400
# 2026-07-12 12:15:29    400
# Name: count, dtype: int64
